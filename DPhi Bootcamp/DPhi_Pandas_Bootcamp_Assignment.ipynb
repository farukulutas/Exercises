# %% [markdown]
# # DPhi Pandas Assignment Details
#
# Dear Learner,
#
# Congratulations, you have studied Pandas all the way through the end of this bootcamp!!! This is the final graded hands-on exercise where you will be accomplishing the below mentioned task.

# %% [markdown]
# # Step 1: Select a Dataset of your choice
#
# *   https://www.kdnuggets.com/datasets/index.html
# *   https://dphi.tech/challenges/#past
# * https://pub.towardsai.net/best-datasets-for-machine-learning-data-science-computer-vision-nlp-ai-c9541058cf4f
# * https://medium.com/analytics-vidhya/top-100-open-source-datasets-for-data-science-cd5a8d67cc3d
#
#
# or you can pick any dataset of your interest on the internet and add reference to it

# %% [markdown]
# # Evaluation Criteria
#
# Your submission will be evaluated using the following criteria:
#
# * You must ensure that the dataset is tabular.
# * You must ask and answer at least 3 questions about the dataset
# *   Your submission must include at least 3 visualizations (graphs)
# *   Your submission must include explanations using markdown cells, apart from the code.
# *   Your work must not be plagiarized i.e. copied for somewhere else.

# %%
# 1- Find the minimum and maximum values of rings in the dataset.
# 2- Are there any missing values in the dataset? Please fill in.
# 3- What are the data types of the columns in the dataset? Specify.

# %% [markdown]
# #Step 2: Perform Data Cleaning/Preparation & Analysis
#
# 1. Create data frame(s) from CSV files
# 2. Perform index operations on data frame(s)
# 3. Apply Group, merge and aggregate data frame(s)
# 4. Check for missing and invalid values in data
# 5. Propose a way to treat the missing and invalid values and implement the same on the dataframe
# 5. Compute the mean, sum, range and other interesting statistics for numeric columns

# %%
#1
import pandas as pd
import matplotlib.pyplot as plt
abalone_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/abalone_data/training_set_label.csv")

#2
df1 = abalone_data.loc[0:10, ["Sex", "Length", "Diameter"]]
df1
# Out:
#    Sex  Length  Diameter
# 0    F   0.525     0.400
# 1    F   0.445     0.325
# 2    M   0.710     0.540
# 3    F   0.680     0.580
# 4    M   0.605     0.470
# 5    I   0.555     0.430
# 6    M   0.510     0.405
# 7    M   0.655     0.520
# 8    M   0.540     0.415
# 9    M   0.515     0.410
# 10   F   0.565     0.450

# %%
df1.plot()

# %%
df2 = abalone_data.iloc[0:10, 3:]
df2
# Out:
#    Height  Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# 0   0.135        0.7140          0.3180          0.1380        0.2080     10
# 1   0.125        0.4550          0.1785          0.1125        0.1400      9
# 2   0.165        1.9590          0.7665          0.2610        0.7800     18
# 3   0.200        1.7870          0.5850          0.4530        0.6000     19
# 4   0.160        1.1735          0.4975          0.2405        0.3450     12
# 5   0.125        0.7005          0.3395          0.1355        0.2095      8
# 6   0.125        0.6925          0.3270          0.1550        0.1805      7
# 7   0.180        1.4920          0.7185          0.3600        0.3550     11
# 8   0.145        0.7400          0.2635          0.1680        0.2450     12
# 9   0.140        0.7355          0.3065          0.1370        0.2000      7

# %%
df2.plot()

# %%
abalone_data.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
abalone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3132 entries, 0 to 3131
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             3132 non-null   object
#  1   Length          3132 non-null   float64
#  2   Diameter        3132 non-null   float64
#  3   Height          3132 non-null   float64
#  4   Whole weight    3132 non-null   float64
#  5   Shucked weight  3132 non-null   float64
#  6   Viscera weight  3132 non-null   float64
#  7   Shell weight    3132 non-null   float64
#  8   Rings           3132 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 220.3+ KB

# %% [markdown]
# Above, the pandas library was imported, the abalone data was read and the data frame was created. Then, 3 columns of this dataframe were taken to show the index operations, and the first 11 values were listed. Other missing columns were also retrieved and the top 10 values were listed. By using dtypes, it was examined which type of values the columns hold. Summary information including info and dtypes is received.

# %%
#3
ring_group = abalone_data.groupby("Rings").mean()
ring_group
# Out:
#          Length  Diameter  ...  Viscera weight  Shell weight
# Rings                      ...
# 2      0.150000  0.100000  ...        0.004000      0.005000
# 3      0.172727  0.126818  ...        0.006455      0.008909
# 4      0.220952  0.160952  ...        0.012964      0.017869
# 5      0.288483  0.211798  ...        0.028348      0.037483
# 6      0.368453  0.278204  ...        0.058881      0.076066
# 7      0.417187  0.317730  ...        0.082758      0.108105
# 8      0.499563  0.386147  ...        0.139149      0.179736
# 9      0.549230  0.427135  ...        0.189006      0.239174
# 10     0.574641  0.449815  ...        0.225064      0.285657
# 11     0.596823  0.469088  ...        0.251238      0.319007
# 12     0.590119  0.463524  ...        0.241888      0.323602
# 13     0.574037  0.452236  ...        0.230012      0.312599
# 14     0.579195  0.458736  ...        0.232195      0.331218
# 15     0.579583  0.460139  ...        0.231549      0.327278
# ...

# %%
abalone_data.plot()

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#   Sex  Length  Diameter  ...  Viscera weight  Shell weight  Rings
# 0   F   0.525     0.400  ...          0.1380        0.2080     10
# 1   F   0.445     0.325  ...          0.1125        0.1400      9
# 2   M   0.710     0.540  ...          0.2610        0.7800     18
# 3   F   0.680     0.580  ...          0.4530        0.6000     19
# 4   M   0.605     0.470  ...          0.2405        0.3450     12
# 5   I   0.555     0.430  ...          0.1355        0.2095      8
# 6   M   0.510     0.405  ...          0.1550        0.1805      7
# 7   M   0.655     0.520  ...          0.3600        0.3550     11
# 8   M   0.540     0.415  ...          0.1680        0.2450     12
# 9   M   0.515     0.410  ...          0.1370        0.2000      7
#
# [10 rows x 9 columns]

# %%
aggted = abalone_data.iloc[0:, 1:].agg(['sum', 'min', 'max', 'mean', 'median'])
aggted
# Out:
#              Length     Diameter  ...  Shell weight         Rings
# sum     1640.250000  1277.705000  ...    749.046000  31157.000000
# min        0.110000     0.090000  ...      0.003000      2.000000
# max        0.815000     0.650000  ...      1.005000     29.000000
# mean       0.523707     0.407952  ...      0.239159      9.947957
# median     0.545000     0.425000  ...      0.235000     10.000000
#
# [5 rows x 8 columns]

# %%
abalone_data.sort_values(by="Rings", ascending=False)
# Out:
#      Sex  Length  Diameter  ...  Viscera weight  Shell weight  Rings
# 1593   F   0.700     0.585  ...          0.3215        0.4750     29
# 3097   M   0.665     0.535  ...          0.3910        0.8850     27
# 1978   M   0.600     0.495  ...          0.1900        0.3750     26
# 1880   F   0.645     0.490  ...          0.2285        0.5100     25
# 2060   M   0.610     0.490  ...          0.2025        0.3600     23
# ...   ..     ...       ...  ...             ...           ...    ...
# 2048   I   0.165     0.120  ...          0.0050        0.0050      3
# 583    I   0.165     0.120  ...          0.0045        0.0140      3
# 111    I   0.190     0.140  ...          0.0050        0.0105      3
# 272    I   0.240     0.175  ...          0.0135        0.0170      3
# 3032   I   0.150     0.100  ...          0.0040        0.0050      2
#
# [3132 rows x 9 columns]

# %%
#4
abalone_data.isnull().value_counts()
# Out:
# Sex    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# False  False   False     False   False         False           False           False         False    3132
# dtype: int64

# %%
abalone_data.isna().value_counts()
# Out:
# Sex    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# False  False   False     False   False         False           False           False         False    3132
# dtype: int64

# %%
#5 No missing values. If there were, I could give the average values for the numeric columns.

#6
abalone_data.describe()
# Out:
#             Length     Diameter  ...  Shell weight        Rings
# count  3132.000000  3132.000000  ...   3132.000000  3132.000000
# mean      0.523707     0.407952  ...      0.239159     9.947957
# std       0.119891     0.099336  ...      0.139040     3.230252
# min       0.110000     0.090000  ...      0.003000     2.000000
# 25%       0.450000     0.350000  ...      0.130000     8.000000
# 50%       0.545000     0.425000  ...      0.235000    10.000000
# 75%       0.615000     0.480000  ...      0.330000    11.000000
# max       0.815000     0.650000  ...      1.005000    29.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# Grouping was done according to the rings using "groupby" and mean values were examined. Data frames that were separated at the beginning were combined with "Merge". Values such as total, minimum, maximum, mean and median were analyzed with the "agg" function. Then the rings were sorted from largest to smallest using the "sort_values" function. Using the "isnull" and "isna" functions with "value_count"s, it was determined that there was no missing data. The summary of the dataset was analyzed with the "describe" function.
#
# The minimum and maximum value of the rings are 2 and 29, respectively. There were no missing values in the dataset. If there were, the numerical categories could be filled in with the average values. There are 7 float, 1 object, 1 int columns in the dataset.
#
# The pyplot module of the matplotlib library was used for graphics. The graphics of the separated data frames were drawn. It can be easily seen that there is a correlation between the total weight and the similar movements in the line of the number of rings. When we look at the overall dataframe from the last chart, it is seen that there is an agglomeration between the number of rings 7.5-12.5.

# %% [markdown]
# # Step 3: Exploration & Inference
#
# 1. Ask at least 3 interesting questions about your dataset
# 2. Answer the questions by computing the results using Pandas library
# 3. Add concluding remarks

# %%
# 1- Could there be distinctive gender-related features among abalones?
abalone_data.loc[ abalone_data['Sex'] == 'M'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Length             0.564925
# Diameter           0.442465
# Height             0.152755
# Whole weight       1.006868
# Shucked weight     0.439529
# Viscera weight     0.219276
# Shell weight       0.286892
# Rings             10.779438
# dtype: float64

# %%
abalone_data.loc[ abalone_data['Sex'] == 'F'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.576886
# Diameter           0.453476
# Height             0.156519
# Whole weight       1.036233
# Shucked weight     0.441432
# Viscera weight     0.228128
# Shell weight       0.300260
# Rings             11.138634
# dtype: float64

# %%
abalone_data.loc[ abalone_data['Sex'] == 'I'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length            0.425903
# Diameter          0.325094
# Height            0.107438
# Whole weight      0.427477
# Shucked weight    0.189413
# Viscera weight    0.091529
# Shell weight      0.126365
# Rings             7.860809
# dtype: float64

# %%
# 2- Is there a relationship between the number of rings of abalones and their body features?
ring_group
# Out:
#          Length  Diameter  ...  Viscera weight  Shell weight
# Rings                      ...
# 2      0.150000  0.100000  ...        0.004000      0.005000
# 3      0.172727  0.126818  ...        0.006455      0.008909
# 4      0.220952  0.160952  ...        0.012964      0.017869
# 5      0.288483  0.211798  ...        0.028348      0.037483
# 6      0.368453  0.278204  ...        0.058881      0.076066
# 7      0.417187  0.317730  ...        0.082758      0.108105
# 8      0.499563  0.386147  ...        0.139149      0.179736
# 9      0.549230  0.427135  ...        0.189006      0.239174
# 10     0.574641  0.449815  ...        0.225064      0.285657
# 11     0.596823  0.469088  ...        0.251238      0.319007
# 12     0.590119  0.463524  ...        0.241888      0.323602
# 13     0.574037  0.452236  ...        0.230012      0.312599
# 14     0.579195  0.458736  ...        0.232195      0.331218
# 15     0.579583  0.460139  ...        0.231549      0.327278
# ...

# %%
abalone_data.sort_values( by='Rings').describe()
# Out:
#             Length     Diameter  ...  Shell weight        Rings
# count  3132.000000  3132.000000  ...   3132.000000  3132.000000
# mean      0.523707     0.407952  ...      0.239159     9.947957
# std       0.119891     0.099336  ...      0.139040     3.230252
# min       0.110000     0.090000  ...      0.003000     2.000000
# 25%       0.450000     0.350000  ...      0.130000     8.000000
# 50%       0.545000     0.425000  ...      0.235000    10.000000
# 75%       0.615000     0.480000  ...      0.330000    11.000000
# max       0.815000     0.650000  ...      1.005000    29.000000
#
# [8 rows x 8 columns]

# %%
# 3- Is there a relationship between the size of the creature and the number of rings?
abalone_data.loc[0: , ['Length', 'Diameter', 'Height', 'Rings']].describe()
# Out:
#             Length     Diameter       Height        Rings
# count  3132.000000  3132.000000  3132.000000  3132.000000
# mean      0.523707     0.407952     0.139277     9.947957
# std       0.119891     0.099336     0.038991     3.230252
# min       0.110000     0.090000     0.000000     2.000000
# 25%       0.450000     0.350000     0.115000     8.000000
# 50%       0.545000     0.425000     0.140000    10.000000
# 75%       0.615000     0.480000     0.165000    11.000000
# max       0.815000     0.650000     0.515000    29.000000

# %% [markdown]
# # Concluding Remarks
# The body features of the average baby abalone are less than that of an adult abalone. In addition, the body features of an average female abalone are slightly more than the male abalone. When viewed with the "describe function", the rings vary between the numbers 2 and 29. However, the numbers where it is most intense are 10 and 11. For abalones, the volume is 0.018 in the 25% portion and the number of rings is 8. In the 50% and 75% portions, their volume is 0.048, and the ring numbers are 10 and 11, respectively. Thus, it can be said that their size is related to the number of rings until they reach a certain maturity. It may not be very accurate to group the ring numbers directly and comment on them. Since there is only 1 of some ring numbers and this is not a sufficient number to comment on the average.
